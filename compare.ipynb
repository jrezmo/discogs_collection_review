# %%
import matplotlib.pyplot as plt
import pandas as pd

dfA = pd.read_csv('out/collection_110421.csv')
dfB = pd.read_csv('out/collection.csv')

dfA['id'].count(), dfB['id'].count()
# Out:
# (234, 241)

# %%
df = pd.merge(dfA, dfB, how='inner', on=['id', 'title', 'url'])
df = df[(df['last_sold_x'] != 0) & (df['last_sold_y'] != 0)]

# %%
view = ['id','title', 'med_x', 'med_y', 'url', 'for_sale_x', 'for_sale_y']
df.query('start_x==0 & start_y==0')[view]
# Out:
#            id                               title  med_x  med_y  \
# 49     711062                   b'Phat Beats 194'   3.93   3.94
# 120  12695505                       b'Zero Waste'   0.00   0.00
# 121    175932          b'Star 69 (What The F**k)'   4.99   4.99
# 137  12066554                             b'Heat'  14.07  14.07
# 187  15202114  b'The Very Polish Cut-Outs Vol. 0'  30.00  30.00
#
#                                           url  for_sale_x  for_sale_y
# 49     https://www.discogs.com/release/711062           0           0
# 120  https://www.discogs.com/release/12695505           0           0
# 121    https://www.discogs.com/release/175932           0           0
# 137  https://www.discogs.com/release/12066554           0           0
# 187  https://www.discogs.com/release/15202114           0           0

# %%
df['med_diff'] = df['med_y'] - df['med_x']
df['med_diff'].mean()
# Out:
# 0.30745689655172415

# %%
view = ['id','title', 'med_x', 'med_y', 'url', 'for_sale_x', 'for_sale_y']
df.sort_values(by='med_diff', ascending=False)[view].head(10)
# Out:
#            id                                 title   med_x   med_y  \
# 206    135671  b'Homework / Discovery / Alive 1997'  126.81  207.68
# 112   8465720                               b'Play'   31.54   34.86
# 69       9134                      b'Life Is Sweet'    6.91   10.14
# 212    158717                            b"Burnin'"   10.61   13.45
# 208  13861184                     b'RTRN II JUNGLE'   19.97   22.48
# 229     11524                       b'Out Of Space'   15.65   17.29
# 222   5310465                          b'Watermark'    9.22   10.49
# 225     13443               b"Where's Your Head At"    3.46    4.61
# 181   6826317                b'The Day Is My Enemy'   42.74   43.81
# 164     28002    b'Last Night A D.J. Saved My Life'    5.76    6.59
#
#                                           url  for_sale_x  for_sale_y
# 206    https://www.discogs.com/release/135671          10          12
# 112   https://www.discogs.com/release/8465720          52          55
# 69       https://www.discogs.com/release/9134          48          47
# 212    https://www.discogs.com/release/158717           4           4
# 208  https://www.discogs.com/release/13861184          53          46
# 229     https://www.discogs.com/release/11524          44          44
# 222   https://www.discogs.com/release/5310465          44          43
# 225     https://www.discogs.com/release/13443          18          20
# 181   https://www.discogs.com/release/6826317          45          47
# 164     https://www.discogs.com/release/28002          54          53

# %%
df['high_diff'] = df['high_y'] - df['high_x']
df['high_diff'].mean()
# Out:
# 0.23284482758620695

# %%
view = ['id','title', 'high_x', 'high_y', 'url', 'for_sale_x', 'for_sale_y']
df.sort_values(by='high_diff', ascending=False)[view].head(10)
# Out:
#           id                               title  high_x  high_y  \
# 4    6424917                       b'Alive 2007'  159.75  177.77
# 159   528435                           b'Rej EP'   27.90   35.00
# 210  9442778                       b'Blue Lines'   26.62   33.18
# 153    21710            b'The Rockafeller Skank'    8.62   13.28
# 212   158717                          b"Burnin'"   20.74   25.00
# 164    28002  b'Last Night A D.J. Saved My Life'    8.07   11.53
# 19   9438479                       b'Protection'   27.50   29.99
# 216  9056717                      b'Outer Edges'   57.64   60.00
# 64     35498           b'What Can You Do For Me'    3.47    5.75
# 125   685577         b'Insane Bangers Volume II'   19.47   21.50
#
#                                          url  for_sale_x  for_sale_y
# 4    https://www.discogs.com/release/6424917          71          49
# 159   https://www.discogs.com/release/528435          35          35
# 210  https://www.discogs.com/release/9442778         282         279
# 153    https://www.discogs.com/release/21710          53          59
# 212   https://www.discogs.com/release/158717           4           4
# 164    https://www.discogs.com/release/28002          54          53
# 19   https://www.discogs.com/release/9438479         205         198
# 216  https://www.discogs.com/release/9056717           1           1
# 64     https://www.discogs.com/release/35498          86          87
# 125   https://www.discogs.com/release/685577          12          13

# %%
df['low_diff'] = df['low_y'] - df['low_x']

# %%
view = ['id','title', 'low_x', 'low_y', 'url', 'for_sale_x', 'for_sale_y']
df.sort_values(by='low_diff', ascending=False)[view].head(10)
# Out:
#           id                                 title  low_x  low_y  \
# 206   135671  b'Homework / Discovery / Alive 1997'  74.90  85.00
# 159   528435                             b'Rej EP'  10.21  18.95
# 29      3554                        b'Quadrastate'   3.00   6.00
# 19   9438479                         b'Protection'  13.50  15.95
# 69      9134                      b'Life Is Sweet'   4.15   5.99
# 212   158717                            b"Burnin'"   5.75   7.07
# 178  1789142              b'Isis / Traits (Remix)'   3.46   4.61
# 87     45303                 b"What's That Noise?"   2.50   3.60
# 65     67138                          b'The Saint'   1.14   1.99
# 218     3795                            b'Dive EP'   1.14   1.90
#
#                                          url  for_sale_x  for_sale_y
# 206   https://www.discogs.com/release/135671          10          12
# 159   https://www.discogs.com/release/528435          35          35
# 29      https://www.discogs.com/release/3554          45          46
# 19   https://www.discogs.com/release/9438479         205         198
# 69      https://www.discogs.com/release/9134          48          47
# 212   https://www.discogs.com/release/158717           4           4
# 178  https://www.discogs.com/release/1789142           4           4
# 87     https://www.discogs.com/release/45303          41          41
# 65     https://www.discogs.com/release/67138          55          57
# 218     https://www.discogs.com/release/3795          28          28

# %%
view = ['id','title', 'low_x', 'med_x', 'high_x', 'low_y', 'med_y', 'high_y', 'url', 'stat_sum']
df['stat_sum'] = df['low_diff'] + df['med_diff'] + df['high_diff']
df.sort_values(by='stat_sum', ascending=False)[view]
# Out:
#            id                                       title  low_x   med_x  \
# 206    135671        b'Homework / Discovery / Alive 1997'  74.90  126.81
# 159    528435                                   b'Rej EP'  10.21   20.75
# 212    158717                                  b"Burnin'"   5.75   10.61
# 210   9442778                               b'Blue Lines'  10.78   20.33
# 153     21710                    b'The Rockafeller Skank'   3.31    5.24
# ..        ...                                         ...    ...     ...
# 110    311765                                  b'Cyclone'   5.75    8.07
# 203    210723                          b'The Killa-Hertz'   0.01    4.95
# 189  15889956  b'The Very Polish Cut-Outs Sampler Vol. 7'   9.18   12.09
# 209  13399060                             b'No Geography'   2.90    6.91
# 4     6424917                               b'Alive 2007'  20.71   59.10
#
#      high_x  low_y   med_y  high_y                                       url  \
# 206  333.00  85.00  207.68  333.00    https://www.discogs.com/release/135671
# 159   27.90  18.95   20.75   35.00    https://www.discogs.com/release/528435
# 212   20.74   7.07   13.45   25.00    https://www.discogs.com/release/158717
# 210   26.62  10.78   19.90   33.18   https://www.discogs.com/release/9442778
# 153    8.62   3.31    5.76   13.28     https://www.discogs.com/release/21710
# ..      ...    ...     ...     ...                                       ...
# 110   16.00   4.28    7.50   16.00    https://www.discogs.com/release/311765
# 203   11.86   0.01    5.19    9.22    https://www.discogs.com/release/210723
# 189   14.93   9.18   11.51   12.67  https://www.discogs.com/release/15889956
# 209   12.99   2.90    5.30    8.00  https://www.discogs.com/release/13399060
# 4    159.75  20.71   32.30  177.77   https://www.discogs.com/release/6424917
#
#      stat_sum
# 206     90.97
# 159     15.84
# 212      8.42
# 210      6.13
# 153      5.18
# ..        ...
# 110     -2.04
# 203     -2.40
# 189     -2.84
# 209     -6.60
# 4       -8.78
#
# [232 rows x 10 columns]
